# %% [markdown]
# ### 블록체인 운영 노드들에 실행 명령

# %%
import requests
import json
import pandas as pd
import hashlib
import random

### 노드의 블록 정보 확인 
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5000/chain", headers=headers)
json.loads(res.text)

headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5001/chain", headers = headers)
json.loads(res.content)


headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5002/chain", headers = headers)
json.loads(res.content)


## 노드 등록하기
headers = {'Content-Type' : 'application/json; charset=utf-8'}
data = {
    "nodes" : "http://localhost:5001"
}
requests.post("http://localhost:5000/nodes/register", headers=headers, data=json.dumps(data)).content

headers = {'Content-Type' : 'application/json; charset=utf-8'}
data = {
    "nodes" : "http://localhost:5002"
}
requests.post("http://localhost:5000/nodes/register", headers=headers, data=json.dumps(data)).content

## transaction (전달 내용) 입력하기
headers = {'Content-Type' : 'application/json; charset=utf-8'}
data = {
    "sender" : "test_from",
    "recipient" : "test_to",
    "amount" : 3,
}
requests.post("http://localhost:5000/transactions/new", headers=headers, data=json.dumps(data)).content
# Out:
# b'{"message":"Transcation will be added to Block {2}"}\n'

# %%
## 노드의 블록정보 확인
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5000/chain", headers=headers)
json.loads(res.content)
# Out:
# {'chain': [{'index': 1,
#    'nonce': 100,
#    'previous_hash': 1,
#    'timestamp': 1727343395.6446605,
#    'transactions': []}],
#  'length': 1}

# %%
## 채굴하기
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5002/mine")
print(res)
# Out:
# <Response [200]>

# %%
## 노드의 블록정보 확인
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5000/chain", headers=headers)
json.loads(res.content)
# Out:
# {'chain': [{'index': 1,
#    'nonce': 100,
#    'previous_hash': 1,
#    'timestamp': 1727343401.2482336,
#    'transactions': []},
#   {'index': 2,
#    'nonce': -411542,
#    'previous_hash': '6ec7d5703a22bf0f91419c539741e321d5eda9a817f1f4e187e627bfb1e2bee8',
#    'timestamp': 1727343754.4914331,
#    'transactions': [{'amount': 3,
#      'recipient': 'test_to',
#      'sender': 'test_from',
#      'timestamp': 1727343444.3372748},
#     {'amount': 0.1,
#      'recipient': 'node_5002',
#      'sender': 'master',
#      'timestamp': 1727343754.4914331}]}],
#  'length': 2}

# %%
## 노드의 블록정보 확인
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5001/chain", headers=headers)
json.loads(res.content)
# Out:
# {'chain': [{'index': 1,
#    'nonce': 100,
#    'previous_hash': 1,
#    'timestamp': 1727343401.2482336,
#    'transactions': []},
#   {'index': 2,
#    'nonce': -411542,
#    'previous_hash': '6ec7d5703a22bf0f91419c539741e321d5eda9a817f1f4e187e627bfb1e2bee8',
#    'timestamp': 1727343754.4914331,
#    'transactions': [{'amount': 3,
#      'recipient': 'test_to',
#      'sender': 'test_from',
#      'timestamp': 1727343444.3372748},
#     {'amount': 0.1,
#      'recipient': 'node_5002',
#      'sender': 'master',
#      'timestamp': 1727343754.4914331}]}],
#  'length': 2}

# %%
## 노드의 블록정보 확인
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5002/chain", headers=headers)
json.loads(res.content)
# Out:
# {'chain': [{'index': 1,
#    'nonce': 100,
#    'previous_hash': 1,
#    'timestamp': 1727343401.2482336,
#    'transactions': []},
#   {'index': 2,
#    'nonce': -411542,
#    'previous_hash': '6ec7d5703a22bf0f91419c539741e321d5eda9a817f1f4e187e627bfb1e2bee8',
#    'timestamp': 1727343754.4914331,
#    'transactions': [{'amount': 3,
#      'recipient': 'test_to',
#      'sender': 'test_from',
#      'timestamp': 1727343444.3372748},
#     {'amount': 0.1,
#      'recipient': 'node_5002',
#      'sender': 'master',
#      'timestamp': 1727343754.4914331}]}],
#  'length': 2}

# %%
for t in range(0,3):
    for times in range(0,random.randint(1,4)):
        ## transaction 입력하기
        headers = {'Content-Type' : 'application/json; charset=utf-8'}
        data = {
            "sender": hashlib.sha256(str(random.randint(3,100000)).encode()).hexdigest(),
            "recipient": hashlib.sha256(str(random.randint(3,100000)).encode()).hexdigest(),
            "amount": random.randint(1,200),
        }
        requests.post("http://localhost:5000/transactions/new", headers=headers, data=json.dumps(data)).content


    ##  채굴하기
    headers = {'Content-Type' : 'application/json; charset=utf-8'}
    res = requests.get("http://localhost:5000/mine")
    # print(res)
print(res.text)

## transaction 입력하기
headers = {'Content-Type' : 'application/json; charset=utf-8'}
data = {
        "sender": hashlib.sha256(str(random.randint(3,100000)).encode()).hexdigest(),
        "recipient": hashlib.sha256(str(random.randint(3,100000)).encode()).hexdigest(),
    "amount": 3,
}
requests.post("http://localhost:5000/transactions/new", headers=headers, data=json.dumps(data)).content
# Out:
# {"index":10,"message":"new block completed","nonce":-349990,"previous_hash":"ea29515e93a81e4798c5e260a50227e62bebf2bda65aefb0f64f0ede0ea40483","transaction":[{"amount":51,"recipient":"61e5047257bec79d2013f0df344d291e2ad9f959caca04cee011a4a06b03fdb6","sender":"b3a31985c0cc9dbe9485c4dc2ead7aba3b99f573d2cb35963ee944941197c927","timestamp":1727344367.3901045},{"amount":43,"recipient":"2b5276239f8a24d6cc1a992d3a43eb3c947812a5961f9980badd833731d6f855","sender":"fc97b8a21558dde1a78ff859f1846a276db1ff4e1e192cbcc00791a24dcb1710","timestamp":1727344373.5305455},{"amount":0.1,"recipient":"node_5000","sender":"master","timestamp":1727344379.7376976}]}
# b'{"message":"Transcation will be added to Block {11}"}\n'

# %%
## 노드의 거래내역 점검
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5000/chain", headers=headers)
json.loads(res.content)
# Out:
# {'chain': [{'index': 1,
#    'nonce': 100,
#    'previous_hash': 1,
#    'timestamp': 1727343401.2482336,
#    'transactions': []},
#   {'index': 2,
#    'nonce': -411542,
#    'previous_hash': '6ec7d5703a22bf0f91419c539741e321d5eda9a817f1f4e187e627bfb1e2bee8',
#    'timestamp': 1727343754.4914331,
#    'transactions': [{'amount': 3,
#      'recipient': 'test_to',
#      'sender': 'test_from',
#      'timestamp': 1727343444.3372748},
#     {'amount': 0.1,
#      'recipient': 'node_5002',
#      'sender': 'master',
#      'timestamp': 1727343754.4914331}]},
#   {'index': 3,
#    'nonce': 410487,
#    'previous_hash': 'f94ed87ccba704909ada8fde97a91ed7415f1265478f3bcfb7437944b853c5e3',
#    'timestamp': 1727344080.0929873,
#    'transactions': [{'amount': 3,
#      'recipient': 'test_to',
#      'sender': 'test_from',
#      'timestamp': 1727343442.2708228},
#     {'amount': 198,
#      'recipient': 'e770b253759b7f653f3d72317e9392bb55b7eeb6c3824fa1b2c82de5cbe3e685',
#      'sender': '37efaec7feed770b007cf6c0c0ffbf306b1410cd5cdef23bd89dcb3db617e4d4',
#      'timestamp': 1727344073.8434129},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344080.0929873}]},
#   {'index': 4,
#    'nonce': 454639,
#    'previous_hash': 'c529c329239d52c05b2032de54b58e16b8e8880ebc6a137d45d7764ff7feea2e',
#    'timestamp': 1727344104.660171,
#    'transactions': [{'amount': 151,
#      'recipient': '91d3be9711dd918748d33ee8fc0c6ceaea73e6e5baf76b9b6eeddf924707d178',
#      'sender': '989436753419e46c506338a4e9ca992b47839c291d2e53f4279915773e2332ed',
#      'timestamp': 1727344098.508498},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344104.660171}]},
#   {'index': 5,
#    'nonce': -56735,
#    'previous_hash': '07a14de42ffb27af58f0439cf5bd55b66445c9cea9c582723972b953340341ac',
#    'timestamp': 1727344155.2883532,
#    'transactions': [{'amount': 132,
#      'recipient': '9daa98ce3a24c2264ed088bb0d65b398e9967e8d16bb6e31467c1fd3a0cd9584',
#      'sender': '8d1895d735ca50045a9a564191eca778d0de266e5ee5fb040849380805a0cf3d',
#      'timestamp': 1727344123.0714762},
#     {'amount': 35,
#      'recipient': 'f757bb435f556e40259f0a79889e10145dbc4dd1a1f681c292bf783a85f21799',
#      'sender': '67c2626a09e5cf7453f59d2d332fee420cbaf53f023b1112b78a217539ab3a89',
#      'timestamp': 1727344130.8464184},
#     {'amount': 164,
#      'recipient': '9e3bb57b68b7b0ac801507997c41fe974cd8fa3fc56a57b4d7f48b32d87f39a7',
#      'sender': 'e64dfaa81efcf596adf4d043107d69dc489c751db7645d72195139189401b364',
#      'timestamp': 1727344136.933109},
#     {'amount': 66,
#      'recipient': '4874d8eb8a6fb3192faf48cc0bb608aebdba8d4a236914096a9ea5656f1ba852',
#      'sender': 'ef3195724b5f047e8c773e9207fdb2e34b6db4accdc8486cac54d76c0b509d52',
#      'timestamp': 1727344143.0459607},
#     {'amount': 50,
#      'recipient': '122961871d9f94be9a62259af5decbdebd96347b4ce91d4fb5fbf26e57a1a7d2',
#      'sender': '0bf5f896544da6d0c5943d37da287a49065759bb67ba62f2719ca12cf2be9fe8',
#      'timestamp': 1727344149.1566083},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344155.2883532}]},
#   {'index': 6,
#    'nonce': 652873,
#    'previous_hash': '9a38a3558bfb546d2014854a8913f5be7aaef50b18190f2d05f0f20e0a149cdb',
#    'timestamp': 1727344192.2034452,
#    'transactions': [{'amount': 167,
#      'recipient': '6a91389bf293538f8bfd1747ffc38730176f9e72e8ed7004fabc8cd25e69df6b',
#      'sender': 'cc23aa7f54460bed8e190dea9ee2f6e56ab2dc8756e87704bf158c2df4531aa8',
#      'timestamp': 1727344173.7334228},
#     {'amount': 77,
#      'recipient': '5e6e28537d535ba8b7dd25bc42f0bae0d439d4fc29afe473f3b738778906dadb',
#      'sender': 'dd992cadace21afab56ffd7409f7dd892e24e9acd73e83cd02c574bc0b813a28',
#      'timestamp': 1727344179.8681774},
#     {'amount': 78,
#      'recipient': 'fd65ddd3504ba0bea2d154a7e466867a101c0d026890d591b95e3fbd10725ee3',
#      'sender': '2645b98ce9d6e36960b2ddcaffd52e34d43009eebf4221266b84a1023db8ae54',
#      'timestamp': 1727344186.028217},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344192.2034452}]},
#   {'index': 7,
#    'nonce': -21989,
#    'previous_hash': 'fbbf1d0c88849af08e27d35f8bf731279f7c475d454afc696e707eb0c4393cde',
#    'timestamp': 1727344235.2453952,
#    'transactions': [{'amount': 142,
#      'recipient': '974668691e09c5a6dad917f1ccaa3f01ade0badf6e59f4a6d54d572606e2eda0',
#      'sender': '0cfa9d00b78e91fbf21e79964f091202d76f4fb25830490af2c56575f9364529',
#      'timestamp': 1727344210.6157877},
#     {'amount': 52,
#      'recipient': '990ff0d6681926f50f55b73f434e1720cd7ca0dbc3c89e99b2f95382e0011756',
#      'sender': 'f298962f0ed08495b28111162cef4b19b555dd8c1885dbdce9ccebafec8b2e42',
#      'timestamp': 1727344216.7871275},
#     {'amount': 130,
#      'recipient': 'b3579bf7a2ee9543ef4d3ec678173a0c0cb33b10295f291e3f096e98dfe06bab',
#      'sender': '48eb17359fc30be8434cd50076e935f91b9079259efde61c29cd97f0b51ef189',
#      'timestamp': 1727344222.9258544},
#     {'amount': 81,
#      'recipient': '5b6cefbd82c485f8ff75fbab827ce141a84e3494ce2c853b352c85687d2db9d6',
#      'sender': '0f6ef22dc2204922df7d482623486326f703f875cae11f9098038fa81ec87f03',
#      'timestamp': 1727344229.0891502},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344235.2453952}]},
#   {'index': 8,
#    'nonce': -449166,
#    'previous_hash': 'c069d74ed7ec088e4bd88f9d792bdcb9f22b6f085be83d2c077c577a6d9a42fa',
#    'timestamp': 1727344311.9533494,
#    'transactions': [{'amount': 110,
#      'recipient': '2f298f418a8b01dffbf28a2a2a198774bf91d6d25214d9553f852136ff169ed6',
#      'sender': '4242ffbd4feb2e1c87ca13421a9a2440507da0daf66d378b401808b154386d0e',
#      'timestamp': 1727344299.5687058},
#     {'amount': 75,
#      'recipient': '14ecf57f2e1c1093e080076e334c1927623d291883160c2326505a9909fbe49e',
#      'sender': 'c5ea45d255a440bc7d1e8ad9d3b21de8cd1c71fd2f52fe47550b0504bf9aa461',
#      'timestamp': 1727344305.7229261},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344311.9533494}]},
#   {'index': 9,
#    'nonce': -494207,
#    'previous_hash': '0373fe9ad764278eadf69645dbf1a596fa7e6da82656178583e2821405d09682',
#    'timestamp': 1727344348.9221528,
#    'transactions': [{'amount': 32,
#      'recipient': 'bba05902dd51ecac9f9b9df0c65fd1d7a3ee04de6b437c6ffe52a9db88a37a37',
#      'sender': '8c649730f8e20808d211263a783b0e0749f75f5e04c7259703724e834674e450',
#      'timestamp': 1727344330.4196763},
#     {'amount': 70,
#      'recipient': 'bfed65e0ee3b331187d31bd503dcbad42f17bf749b37c34f64cf8bbc3007073c',
#      'sender': 'e6dff2507e2cded9b40679886cfb3d1efdf6c93e04429a15aa32bf7c42379014',
#      'timestamp': 1727344336.5522332},
#     {'amount': 142,
#      'recipient': '6ed378745ce22d2312d8e608e2f628ae274373031c9efcd6497c5916caa2ed76',
#      'sender': '6d43658c3319ec1b3b8f1c7f2b65c5710b8d93b78f1b4bcda6bb2410689b490d',
#      'timestamp': 1727344342.7191525},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344348.9221528}]},
#   {'index': 10,
#    'nonce': -349990,
#    'previous_hash': 'ea29515e93a81e4798c5e260a50227e62bebf2bda65aefb0f64f0ede0ea40483',
#    'timestamp': 1727344379.7376976,
#    'transactions': [{'amount': 51,
#      'recipient': '61e5047257bec79d2013f0df344d291e2ad9f959caca04cee011a4a06b03fdb6',
#      'sender': 'b3a31985c0cc9dbe9485c4dc2ead7aba3b99f573d2cb35963ee944941197c927',
#      'timestamp': 1727344367.3901045},
#     {'amount': 43,
#      'recipient': '2b5276239f8a24d6cc1a992d3a43eb3c947812a5961f9980badd833731d6f855',
#      'sender': 'fc97b8a21558dde1a78ff859f1846a276db1ff4e1e192cbcc00791a24dcb1710',
#      'timestamp': 1727344373.5305455},
#     {'amount': 0.1,
#      'recipient': 'node_5000',
#      'sender': 'master',
#      'timestamp': 1727344379.7376976}]}],
#  'length': 10}

# %%
##  채굴하기
headers = {'Content-Type' : 'application/json; charset=utf-8'}
res = requests.get("http://localhost:5000/mine")
print(res)
print(res.text)
# Out:
# <Response [200]>
# {"index":11,"message":"new block completed","nonce":-975822,"previous_hash":"1bc24681f8c2a03b331a42cd68e3b6c01ba9e3caf015f49f0752245b52eadfeb","transaction":[{"amount":3,"recipient":"d32fb5e7b4becf187a8af67e8f64e18968650756ff931f80801b56b68790a6ae","sender":"62620c4487e028fb101634e061f1f1d2ad04c9231e438e8a21179ec01ba80144","timestamp":1727344398.081153},{"amount":0.1,"recipient":"node_5000","sender":"master","timestamp":1727344429.0134346}]}

# %%
## 1번 노드 상태 받기!!

headers = {'Content-Type' : 'application/json; charset=utf-8'}
a = requests.get("http://localhost:5000/chain", headers=headers)
status_json = json.loads(a.text)
status_json['chain']
# Out:
# [{'index': 1,
#   'nonce': 100,
#   'previous_hash': 1,
#   'timestamp': 1727343401.2482336,
#   'transactions': []},
#  {'index': 2,
#   'nonce': -411542,
#   'previous_hash': '6ec7d5703a22bf0f91419c539741e321d5eda9a817f1f4e187e627bfb1e2bee8',
#   'timestamp': 1727343754.4914331,
#   'transactions': [{'amount': 3,
#     'recipient': 'test_to',
#     'sender': 'test_from',
#     'timestamp': 1727343444.3372748},
#    {'amount': 0.1,
#     'recipient': 'node_5002',
#     'sender': 'master',
#     'timestamp': 1727343754.4914331}]},
#  {'index': 3,
#   'nonce': 410487,
#   'previous_hash': 'f94ed87ccba704909ada8fde97a91ed7415f1265478f3bcfb7437944b853c5e3',
#   'timestamp': 1727344080.0929873,
#   'transactions': [{'amount': 3,
#     'recipient': 'test_to',
#     'sender': 'test_from',
#     'timestamp': 1727343442.2708228},
#    {'amount': 198,
#     'recipient': 'e770b253759b7f653f3d72317e9392bb55b7eeb6c3824fa1b2c82de5cbe3e685',
#     'sender': '37efaec7feed770b007cf6c0c0ffbf306b1410cd5cdef23bd89dcb3db617e4d4',
#     'timestamp': 1727344073.8434129},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344080.0929873}]},
#  {'index': 4,
#   'nonce': 454639,
#   'previous_hash': 'c529c329239d52c05b2032de54b58e16b8e8880ebc6a137d45d7764ff7feea2e',
#   'timestamp': 1727344104.660171,
#   'transactions': [{'amount': 151,
#     'recipient': '91d3be9711dd918748d33ee8fc0c6ceaea73e6e5baf76b9b6eeddf924707d178',
#     'sender': '989436753419e46c506338a4e9ca992b47839c291d2e53f4279915773e2332ed',
#     'timestamp': 1727344098.508498},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344104.660171}]},
#  {'index': 5,
#   'nonce': -56735,
#   'previous_hash': '07a14de42ffb27af58f0439cf5bd55b66445c9cea9c582723972b953340341ac',
#   'timestamp': 1727344155.2883532,
#   'transactions': [{'amount': 132,
#     'recipient': '9daa98ce3a24c2264ed088bb0d65b398e9967e8d16bb6e31467c1fd3a0cd9584',
#     'sender': '8d1895d735ca50045a9a564191eca778d0de266e5ee5fb040849380805a0cf3d',
#     'timestamp': 1727344123.0714762},
#    {'amount': 35,
#     'recipient': 'f757bb435f556e40259f0a79889e10145dbc4dd1a1f681c292bf783a85f21799',
#     'sender': '67c2626a09e5cf7453f59d2d332fee420cbaf53f023b1112b78a217539ab3a89',
#     'timestamp': 1727344130.8464184},
#    {'amount': 164,
#     'recipient': '9e3bb57b68b7b0ac801507997c41fe974cd8fa3fc56a57b4d7f48b32d87f39a7',
#     'sender': 'e64dfaa81efcf596adf4d043107d69dc489c751db7645d72195139189401b364',
#     'timestamp': 1727344136.933109},
#    {'amount': 66,
#     'recipient': '4874d8eb8a6fb3192faf48cc0bb608aebdba8d4a236914096a9ea5656f1ba852',
#     'sender': 'ef3195724b5f047e8c773e9207fdb2e34b6db4accdc8486cac54d76c0b509d52',
#     'timestamp': 1727344143.0459607},
#    {'amount': 50,
#     'recipient': '122961871d9f94be9a62259af5decbdebd96347b4ce91d4fb5fbf26e57a1a7d2',
#     'sender': '0bf5f896544da6d0c5943d37da287a49065759bb67ba62f2719ca12cf2be9fe8',
#     'timestamp': 1727344149.1566083},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344155.2883532}]},
#  {'index': 6,
#   'nonce': 652873,
#   'previous_hash': '9a38a3558bfb546d2014854a8913f5be7aaef50b18190f2d05f0f20e0a149cdb',
#   'timestamp': 1727344192.2034452,
#   'transactions': [{'amount': 167,
#     'recipient': '6a91389bf293538f8bfd1747ffc38730176f9e72e8ed7004fabc8cd25e69df6b',
#     'sender': 'cc23aa7f54460bed8e190dea9ee2f6e56ab2dc8756e87704bf158c2df4531aa8',
#     'timestamp': 1727344173.7334228},
#    {'amount': 77,
#     'recipient': '5e6e28537d535ba8b7dd25bc42f0bae0d439d4fc29afe473f3b738778906dadb',
#     'sender': 'dd992cadace21afab56ffd7409f7dd892e24e9acd73e83cd02c574bc0b813a28',
#     'timestamp': 1727344179.8681774},
#    {'amount': 78,
#     'recipient': 'fd65ddd3504ba0bea2d154a7e466867a101c0d026890d591b95e3fbd10725ee3',
#     'sender': '2645b98ce9d6e36960b2ddcaffd52e34d43009eebf4221266b84a1023db8ae54',
#     'timestamp': 1727344186.028217},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344192.2034452}]},
#  {'index': 7,
#   'nonce': -21989,
#   'previous_hash': 'fbbf1d0c88849af08e27d35f8bf731279f7c475d454afc696e707eb0c4393cde',
#   'timestamp': 1727344235.2453952,
#   'transactions': [{'amount': 142,
#     'recipient': '974668691e09c5a6dad917f1ccaa3f01ade0badf6e59f4a6d54d572606e2eda0',
#     'sender': '0cfa9d00b78e91fbf21e79964f091202d76f4fb25830490af2c56575f9364529',
#     'timestamp': 1727344210.6157877},
#    {'amount': 52,
#     'recipient': '990ff0d6681926f50f55b73f434e1720cd7ca0dbc3c89e99b2f95382e0011756',
#     'sender': 'f298962f0ed08495b28111162cef4b19b555dd8c1885dbdce9ccebafec8b2e42',
#     'timestamp': 1727344216.7871275},
#    {'amount': 130,
#     'recipient': 'b3579bf7a2ee9543ef4d3ec678173a0c0cb33b10295f291e3f096e98dfe06bab',
#     'sender': '48eb17359fc30be8434cd50076e935f91b9079259efde61c29cd97f0b51ef189',
#     'timestamp': 1727344222.9258544},
#    {'amount': 81,
#     'recipient': '5b6cefbd82c485f8ff75fbab827ce141a84e3494ce2c853b352c85687d2db9d6',
#     'sender': '0f6ef22dc2204922df7d482623486326f703f875cae11f9098038fa81ec87f03',
#     'timestamp': 1727344229.0891502},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344235.2453952}]},
#  {'index': 8,
#   'nonce': -449166,
#   'previous_hash': 'c069d74ed7ec088e4bd88f9d792bdcb9f22b6f085be83d2c077c577a6d9a42fa',
#   'timestamp': 1727344311.9533494,
#   'transactions': [{'amount': 110,
#     'recipient': '2f298f418a8b01dffbf28a2a2a198774bf91d6d25214d9553f852136ff169ed6',
#     'sender': '4242ffbd4feb2e1c87ca13421a9a2440507da0daf66d378b401808b154386d0e',
#     'timestamp': 1727344299.5687058},
#    {'amount': 75,
#     'recipient': '14ecf57f2e1c1093e080076e334c1927623d291883160c2326505a9909fbe49e',
#     'sender': 'c5ea45d255a440bc7d1e8ad9d3b21de8cd1c71fd2f52fe47550b0504bf9aa461',
#     'timestamp': 1727344305.7229261},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344311.9533494}]},
#  {'index': 9,
#   'nonce': -494207,
#   'previous_hash': '0373fe9ad764278eadf69645dbf1a596fa7e6da82656178583e2821405d09682',
#   'timestamp': 1727344348.9221528,
#   'transactions': [{'amount': 32,
#     'recipient': 'bba05902dd51ecac9f9b9df0c65fd1d7a3ee04de6b437c6ffe52a9db88a37a37',
#     'sender': '8c649730f8e20808d211263a783b0e0749f75f5e04c7259703724e834674e450',
#     'timestamp': 1727344330.4196763},
#    {'amount': 70,
#     'recipient': 'bfed65e0ee3b331187d31bd503dcbad42f17bf749b37c34f64cf8bbc3007073c',
#     'sender': 'e6dff2507e2cded9b40679886cfb3d1efdf6c93e04429a15aa32bf7c42379014',
#     'timestamp': 1727344336.5522332},
#    {'amount': 142,
#     'recipient': '6ed378745ce22d2312d8e608e2f628ae274373031c9efcd6497c5916caa2ed76',
#     'sender': '6d43658c3319ec1b3b8f1c7f2b65c5710b8d93b78f1b4bcda6bb2410689b490d',
#     'timestamp': 1727344342.7191525},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344348.9221528}]},
#  {'index': 10,
#   'nonce': -349990,
#   'previous_hash': 'ea29515e93a81e4798c5e260a50227e62bebf2bda65aefb0f64f0ede0ea40483',
#   'timestamp': 1727344379.7376976,
#   'transactions': [{'amount': 51,
#     'recipient': '61e5047257bec79d2013f0df344d291e2ad9f959caca04cee011a4a06b03fdb6',
#     'sender': 'b3a31985c0cc9dbe9485c4dc2ead7aba3b99f573d2cb35963ee944941197c927',
#     'timestamp': 1727344367.3901045},
#    {'amount': 43,
#     'recipient': '2b5276239f8a24d6cc1a992d3a43eb3c947812a5961f9980badd833731d6f855',
#     'sender': 'fc97b8a21558dde1a78ff859f1846a276db1ff4e1e192cbcc00791a24dcb1710',
#     'timestamp': 1727344373.5305455},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344379.7376976}]},
#  {'index': 11,
#   'nonce': -975822,
#   'previous_hash': '1bc24681f8c2a03b331a42cd68e3b6c01ba9e3caf015f49f0752245b52eadfeb',
#   'timestamp': 1727344429.0134346,
#   'transactions': [{'amount': 3,
#     'recipient': 'd32fb5e7b4becf187a8af67e8f64e18968650756ff931f80801b56b68790a6ae',
#     'sender': '62620c4487e028fb101634e061f1f1d2ad04c9231e438e8a21179ec01ba80144',
#     'timestamp': 1727344398.081153},
#    {'amount': 0.1,
#     'recipient': 'node_5000',
#     'sender': 'master',
#     'timestamp': 1727344429.0134346}]}]

# %%
tx_amount_l = []
tx_sender_l = []
tx_reciv_l  = []
tx_time_l   = []

for chain_index in range(len(status_json['chain'])):
    chain_tx = status_json['chain'][chain_index]['transactions']
    for each_tx in range(len(chain_tx)):
        tx_amount_l.append(chain_tx[each_tx]['amount'])
        tx_sender_l.append(chain_tx[each_tx]['sender'])
        tx_reciv_l.append(chain_tx[each_tx]['recipient'])
        tx_time_l.append(chain_tx[each_tx]['timestamp'])
        
df_tx = pd.DataFrame()
df_tx['timestamp'] = tx_time_l  
df_tx['sender'] = tx_sender_l 
df_tx['recipient'] = tx_reciv_l
df_tx['amount'] = tx_amount_l   
df_tx
# Out:
#        timestamp                                             sender  \
# 0   1.727343e+09                                          test_from
# 1   1.727344e+09                                             master
# 2   1.727343e+09                                          test_from
# 3   1.727344e+09  37efaec7feed770b007cf6c0c0ffbf306b1410cd5cdef2...
# 4   1.727344e+09                                             master
# 5   1.727344e+09  989436753419e46c506338a4e9ca992b47839c291d2e53...
# 6   1.727344e+09                                             master
# 7   1.727344e+09  8d1895d735ca50045a9a564191eca778d0de266e5ee5fb...
# 8   1.727344e+09  67c2626a09e5cf7453f59d2d332fee420cbaf53f023b11...
# 9   1.727344e+09  e64dfaa81efcf596adf4d043107d69dc489c751db7645d...
# 10  1.727344e+09  ef3195724b5f047e8c773e9207fdb2e34b6db4accdc848...
# 11  1.727344e+09  0bf5f896544da6d0c5943d37da287a49065759bb67ba62...
# 12  1.727344e+09                                             master
# 13  1.727344e+09  cc23aa7f54460bed8e190dea9ee2f6e56ab2dc8756e877...
# 14  1.727344e+09  dd992cadace21afab56ffd7409f7dd892e24e9acd73e83...
# 15  1.727344e+09  2645b98ce9d6e36960b2ddcaffd52e34d43009eebf4221...
# 16  1.727344e+09                                             master
# 17  1.727344e+09  0cfa9d00b78e91fbf21e79964f091202d76f4fb2583049...
# 18  1.727344e+09  f298962f0ed08495b28111162cef4b19b555dd8c1885db...
# 19  1.727344e+09  48eb17359fc30be8434cd50076e935f91b9079259efde6...
# 20  1.727344e+09  0f6ef22dc2204922df7d482623486326f703f875cae11f...
# 21  1.727344e+09                                             master
# 22  1.727344e+09  4242ffbd4feb2e1c87ca13421a9a2440507da0daf66d37...
# 23  1.727344e+09  c5ea45d255a440bc7d1e8ad9d3b21de8cd1c71fd2f52fe...
# 24  1.727344e+09                                             master
# 25  1.727344e+09  8c649730f8e20808d211263a783b0e0749f75f5e04c725...
# 26  1.727344e+09  e6dff2507e2cded9b40679886cfb3d1efdf6c93e04429a...
# 27  1.727344e+09  6d43658c3319ec1b3b8f1c7f2b65c5710b8d93b78f1b4b...
# 28  1.727344e+09                                             master
# 29  1.727344e+09  b3a31985c0cc9dbe9485c4dc2ead7aba3b99f573d2cb35...
# 30  1.727344e+09  fc97b8a21558dde1a78ff859f1846a276db1ff4e1e192c...
# 31  1.727344e+09                                             master
# 32  1.727344e+09  62620c4487e028fb101634e061f1f1d2ad04c9231e438e...
# 33  1.727344e+09                                             master
#
#                                             recipient  amount
# 0                                             test_to     3.0
# 1                                           node_5002     0.1
# 2                                             test_to     3.0
# 3   e770b253759b7f653f3d72317e9392bb55b7eeb6c3824f...   198.0
# 4                                           node_5000     0.1
# 5   91d3be9711dd918748d33ee8fc0c6ceaea73e6e5baf76b...   151.0
# 6                                           node_5000     0.1
# 7   9daa98ce3a24c2264ed088bb0d65b398e9967e8d16bb6e...   132.0
# 8   f757bb435f556e40259f0a79889e10145dbc4dd1a1f681...    35.0
# 9   9e3bb57b68b7b0ac801507997c41fe974cd8fa3fc56a57...   164.0
# 10  4874d8eb8a6fb3192faf48cc0bb608aebdba8d4a236914...    66.0
# 11  122961871d9f94be9a62259af5decbdebd96347b4ce91d...    50.0
# 12                                          node_5000     0.1
# 13  6a91389bf293538f8bfd1747ffc38730176f9e72e8ed70...   167.0
# 14  5e6e28537d535ba8b7dd25bc42f0bae0d439d4fc29afe4...    77.0
# 15  fd65ddd3504ba0bea2d154a7e466867a101c0d026890d5...    78.0
# 16                                          node_5000     0.1
# 17  974668691e09c5a6dad917f1ccaa3f01ade0badf6e59f4...   142.0
# 18  990ff0d6681926f50f55b73f434e1720cd7ca0dbc3c89e...    52.0
# 19  b3579bf7a2ee9543ef4d3ec678173a0c0cb33b10295f29...   130.0
# 20  5b6cefbd82c485f8ff75fbab827ce141a84e3494ce2c85...    81.0
# 21                                          node_5000     0.1
# 22  2f298f418a8b01dffbf28a2a2a198774bf91d6d25214d9...   110.0
# 23  14ecf57f2e1c1093e080076e334c1927623d291883160c...    75.0
# 24                                          node_5000     0.1
# 25  bba05902dd51ecac9f9b9df0c65fd1d7a3ee04de6b437c...    32.0
# 26  bfed65e0ee3b331187d31bd503dcbad42f17bf749b37c3...    70.0
# 27  6ed378745ce22d2312d8e608e2f628ae274373031c9efc...   142.0
# 28                                          node_5000     0.1
# 29  61e5047257bec79d2013f0df344d291e2ad9f959caca04...    51.0
# 30  2b5276239f8a24d6cc1a992d3a43eb3c947812a5961f99...    43.0
# 31                                          node_5000     0.1
# 32  d32fb5e7b4becf187a8af67e8f64e18968650756ff931f...     3.0
# 33                                          node_5000     0.1

# %%
df_sended = pd.DataFrame(df_tx.groupby('sender')['amount'].sum()).reset_index()
df_sended.columns = ['user','sended_amount']
df_received= pd.DataFrame(df_tx.groupby('recipient')['amount'].sum()).reset_index()
df_received.columns = ['user','received_amount']
df_received
# Out:
#                                                  user  received_amount
# 0   122961871d9f94be9a62259af5decbdebd96347b4ce91d...             50.0
# 1   14ecf57f2e1c1093e080076e334c1927623d291883160c...             75.0
# 2   2b5276239f8a24d6cc1a992d3a43eb3c947812a5961f99...             43.0
# 3   2f298f418a8b01dffbf28a2a2a198774bf91d6d25214d9...            110.0
# 4   4874d8eb8a6fb3192faf48cc0bb608aebdba8d4a236914...             66.0
# 5   5b6cefbd82c485f8ff75fbab827ce141a84e3494ce2c85...             81.0
# 6   5e6e28537d535ba8b7dd25bc42f0bae0d439d4fc29afe4...             77.0
# 7   61e5047257bec79d2013f0df344d291e2ad9f959caca04...             51.0
# 8   6a91389bf293538f8bfd1747ffc38730176f9e72e8ed70...            167.0
# 9   6ed378745ce22d2312d8e608e2f628ae274373031c9efc...            142.0
# 10  91d3be9711dd918748d33ee8fc0c6ceaea73e6e5baf76b...            151.0
# 11  974668691e09c5a6dad917f1ccaa3f01ade0badf6e59f4...            142.0
# 12  990ff0d6681926f50f55b73f434e1720cd7ca0dbc3c89e...             52.0
# 13  9daa98ce3a24c2264ed088bb0d65b398e9967e8d16bb6e...            132.0
# 14  9e3bb57b68b7b0ac801507997c41fe974cd8fa3fc56a57...            164.0
# 15  b3579bf7a2ee9543ef4d3ec678173a0c0cb33b10295f29...            130.0
# 16  bba05902dd51ecac9f9b9df0c65fd1d7a3ee04de6b437c...             32.0
# 17  bfed65e0ee3b331187d31bd503dcbad42f17bf749b37c3...             70.0
# 18  d32fb5e7b4becf187a8af67e8f64e18968650756ff931f...              3.0
# 19  e770b253759b7f653f3d72317e9392bb55b7eeb6c3824f...            198.0
# 20  f757bb435f556e40259f0a79889e10145dbc4dd1a1f681...             35.0
# 21  fd65ddd3504ba0bea2d154a7e466867a101c0d026890d5...             78.0
# 22                                          node_5000              0.9
# 23                                          node_5002              0.1
# 24                                            test_to              6.0

# %%
df_received.to_json()
# Out:
# '{"user":{"0":"122961871d9f94be9a62259af5decbdebd96347b4ce91d4fb5fbf26e57a1a7d2","1":"14ecf57f2e1c1093e080076e334c1927623d291883160c2326505a9909fbe49e","2":"2b5276239f8a24d6cc1a992d3a43eb3c947812a5961f9980badd833731d6f855","3":"2f298f418a8b01dffbf28a2a2a198774bf91d6d25214d9553f852136ff169ed6","4":"4874d8eb8a6fb3192faf48cc0bb608aebdba8d4a236914096a9ea5656f1ba852","5":"5b6cefbd82c485f8ff75fbab827ce141a84e3494ce2c853b352c85687d2db9d6","6":"5e6e28537d535ba8b7dd25bc42f0bae0d439d4fc29afe473f3b738778906dadb","7":"61e5047257bec79d2013f0df344d291e2ad9f959caca04cee011a4a06b03fdb6","8":"6a91389bf293538f8bfd1747ffc38730176f9e72e8ed7004fabc8cd25e69df6b","9":"6ed378745ce22d2312d8e608e2f628ae274373031c9efcd6497c5916caa2ed76","10":"91d3be9711dd918748d33ee8fc0c6ceaea73e6e5baf76b9b6eeddf924707d178","11":"974668691e09c5a6dad917f1ccaa3f01ade0badf6e59f4a6d54d572606e2eda0","12":"990ff0d6681926f50f55b73f434e1720cd7ca0dbc3c89e99b2f95382e0011756","13":"9daa98ce3a24c2264ed088bb0d65b398e9967e8d16bb6e31467c1fd3a0cd9584","14":"9e3bb57b68b7b0ac801507997c41fe974cd8fa3fc56a57b4d7f48b32d87f39a7","15":"b3579bf7a2ee9543ef4d3ec678173a0c0cb33b10295f291e3f096e98dfe06bab","16":"bba05902dd51ecac9f9b9df0c65fd1d7a3ee04de6b437c6ffe52a9db88a37a37","17":"bfed65e0ee3b331187d31bd503dcbad42f17bf749b37c34f64cf8bbc3007073c","18":"d32fb5e7b4becf187a8af67e8f64e18968650756ff931f80801b56b68790a6ae","19":"e770b253759b7f653f3d72317e9392bb55b7eeb6c3824fa1b2c82de5cbe3e685","20":"f757bb435f556e40259f0a79889e10145dbc4dd1a1f681c292bf783a85f21799","21":"fd65ddd3504ba0bea2d154a7e466867a101c0d026890d591b95e3fbd10725ee3","22":"node_5000","23":"node_5002","24":"test_to"},"received_amount":{"0":50.0,"1":75.0,"2":43.0,"3":110.0,"4":66.0,"5":81.0,"6":77.0,"7":51.0,"8":167.0,"9":142.0,"10":151.0,"11":142.0,"12":52.0,"13":132.0,"14":164.0,"15":130.0,"16":32.0,"17":70.0,"18":3.0,"19":198.0,"20":35.0,"21":78.0,"22":0.9,"23":0.1,"24":6.0}}'
